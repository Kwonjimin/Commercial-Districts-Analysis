# %% [markdown]
# # 카페 브랜드 상권 분석

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import folium
import os
import json
import warnings
warnings.filterwarnings('ignore')

# %%
# 한글 폰트 설정
plt.rc("font", family='NanumGothic')
plt.rc("axes", unicode_minus=False)

# %%
# 레티나 디스플레이로 폰트가 선명하게 표시되도록 함
from IPython.display import set_matplotlib_formats
set_matplotlib_formats("retina")

# %% [markdown]
# ## 데이터 불러오기

# %%
dir_path="data/"
file_list=os.listdir(dir_path)
file_list
# Out:
# ['seoul_municipalities_geo_simple.json',
#  '소상공인시장진흥공단_상가(상권)정보_강원_202012.csv',
#  '소상공인시장진흥공단_상가(상권)정보_경기_202012.csv',
#  '소상공인시장진흥공단_상가(상권)정보_경남_202012.csv',
#  '소상공인시장진흥공단_상가(상권)정보_경북_202012.csv',
#  '소상공인시장진흥공단_상가(상권)정보_광주_202012.csv',
#  '소상공인시장진흥공단_상가(상권)정보_대구_202012.csv',
#  '소상공인시장진흥공단_상가(상권)정보_대전_202012.csv',
#  '소상공인시장진흥공단_상가(상권)정보_부산_202012.csv',
#  '소상공인시장진흥공단_상가(상권)정보_서울_202012.csv',
#  '소상공인시장진흥공단_상가(상권)정보_세종_202012.csv',
#  '소상공인시장진흥공단_상가(상권)정보_울산_202012.csv',
#  '소상공인시장진흥공단_상가(상권)정보_인천_202012.csv',
#  '소상공인시장진흥공단_상가(상권)정보_전남_202012.csv',
#  '소상공인시장진흥공단_상가(상권)정보_전북_202012.csv',
#  '소상공인시장진흥공단_상가(상권)정보_제주_202012.csv',
#  '소상공인시장진흥공단_상가(상권)정보_충남_202012.csv',
#  '소상공인시장진흥공단_상가(상권)정보_충북_202012.csv']

# %%
# 도시 목록
city_list=[x.split('_')[2] for x in file_list if '.csv' in x]

# %%
while True:
    print("도시 목록 : ",end = '')
    for i in city_list:
        if i is not city_list[-1]: print(i, end=',')
        else : print(i)
    city=input('분석하고 싶은 도시 이름을 입력해주세요 : ')
    if city in city_list : break
    print('도시 목록에 있는 것만 입력해주세요!')
    print('---------------------------------------------------\n')
# Out:
# 도시 목록 : 강원,경기,경남,경북,광주,대구,대전,부산,서울,세종,울산,인천,전남,전북,제주,충남,충북
# 분석하고 싶은 도시 이름을 입력해주세요 : 서울

# %%
df=pd.DataFrame()
for i in file_list:
    if city in i : df=pd.read_csv(dir_path+i,sep="|")
pd.options.display.max_columns = len(df.columns) # 모든 컬럼이 표시되도록 max_columns의 수를 지정
df
# Out:
#           상가업소번호        상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드    상권업종중분류명  \
# 0       17163092  도전최강달인왕만두  NaN         Q       음식       Q01          한식
# 1       17120456         이때  NaN         Q       음식       Q01          한식
# 2       17175350      L.A.D  NaN         Q       음식       Q01          한식
# 3       17175311    제이씨에스푸드  NaN         Q       음식       Q01          한식
# 4       22767534     BYC상신점  상신점         D       소매       D05        의복의류
# ...          ...        ...  ...       ...      ...       ...         ...
# 346572  17222727       현대기림  NaN         D       소매       D10     건강/미용식품
# 346573  17222723     본현대미아점  NaN         D       소매       D10     건강/미용식품
# 346574  17219564      오피스알파  약장수         D       소매       D10     건강/미용식품
# 346575  17219761  앤클라인뉴욕핸드백  NaN         D       소매       D06  가방/신발/액세서리
# 346576  17207617      피움테라피  NaN         F    생활서비스       F01     이/미용/건강
#
#        상권업종소분류코드   상권업종소분류명 표준산업분류코드           표준산업분류명  시도코드    시도명  시군구코드  \
# 0         Q01A01  한식/백반/한정식   I56111           한식 음식점업    11  서울특별시  11740
# 1         Q01A01  한식/백반/한정식   I56111           한식 음식점업    11  서울특별시  11440
# 2         Q01A01  한식/백반/한정식   I56111           한식 음식점업    11  서울특별시  11440
# 3         Q01A01  한식/백반/한정식   I56111           한식 음식점업    11  서울특별시  11620
# 4         D05A07   셔츠/내의/속옷      NaN               NaN    11  서울특별시  11710
# ...          ...        ...      ...               ...   ...    ...    ...
# 346572    D10A04     건강식품판매   G47216        건강보조식품 소매업    11  서울특별시  11200
# 346573    D10A04     건강식품판매   G47216        건강보조식품 소매업    11  서울특별시  11290
# 346574    D10A04     건강식품판매   G47216        건강보조식품 소매업    11  서울특별시  11305
# 346575    D06A10  가방/가죽제품소매   G47430  가방 및 기타 가죽제품 소매업    11  서울특별시  11530
# 346576    F01A03    비만/피부관리      NaN               NaN    11  서울특별시  11350
#
#        시군구명       행정동코드    행정동명       법정동코드   법정동명                 지번코드  \
# 0       강동구  1174056000    고덕2동  1174010200    고덕동  1174010200206930000
# 1       마포구  1144071000     연남동  1144012400    연남동  1144012400203900067
# 2       마포구  1144066000     서교동  1144012000    서교동  1144012000203950112
# 3       관악구  1162066500     서림동  1162010200    신림동  1162010200201180033
# 4       송파구  1171053200    거여2동  1171011300    거여동  1171011300200360000
# ...     ...         ...     ...         ...    ...                  ...
# 346572  성동구  1120065000  성수1가1동  1120011400  성수동1가  1120011400202760017
# 346573  성북구  1129068500    길음2동  1129013400    길음동  1129013400200200001
# 346574  강북구  1130563500    수유3동  1130510300    수유동  1130510300200360037
# 346575  구로구  1153056000    구로5동  1153010200    구로동  1153010200205730000
# 346576  노원구  1135062500  중계2.3동  1135010600    중계동  1135010600205040001
#
#         대지구분코드 대지구분명  지번본번지  지번부번지                    지번주소         도로명코드  \
# 0            1    대지    693    NaN       서울특별시 강동구 고덕동 693  117403124001
# 1            1    대지    390   67.0    서울특별시 마포구 연남동 390-67  114404139119
# 2            1    대지    395  112.0   서울특별시 마포구 서교동 395-112  114404139571
# 3            1    대지    118   33.0    서울특별시 관악구 신림동 118-33  116204160502
# 4            1    대지     36    NaN        서울특별시 송파구 거여동 36  117103123014
# ...        ...   ...    ...    ...                     ...           ...
# 346572       1    대지    276   17.0  서울특별시 성동구 성수동1가 276-17  112003103010
# 346573       1    대지     20    1.0      서울특별시 성북구 길음동 20-1  112903107003
# 346574       1    대지     36   37.0     서울특별시 강북구 수유동 36-37  113054124005
# 346575       1    대지    573    NaN       서울특별시 구로구 구로동 573  115303116005
# 346576       1    대지    504    1.0     서울특별시 노원구 중계동 504-1  113503110005
#
#                       도로명  건물본번지  건물부번지                     건물관리번호       건물명  \
# 0           서울특별시 강동구 고덕로    333    NaN  1174010200102170000018014    고덕그라시움
# 1       서울특별시 마포구 동교로38안길      7    NaN  1144012400103900067027687       NaN
# 2       서울특별시 마포구 잔다리로3안길     23    NaN  1144012000103950112010755       NaN
# 3        서울특별시 관악구 신림로14길      3    NaN  1162010200101180033018722       NaN
# 4           서울특별시 송파구 오금로    527    NaN  1171011300100360000022458      성암빌딩
# ...                   ...    ...    ...                        ...       ...
# 346572      서울특별시 성동구 뚝섬로    366   72.0  1120011400102760017009013       NaN
# 346573     서울특별시 성북구 동소문로    315    NaN  1129013400100200001025204  현대백화점미아점
# 346574   서울특별시 강북구 노해로17길     62    1.0  1130510300100360037035171       NaN
# 346575    서울특별시 구로구 구로중앙로    152    NaN  1153010200105730000020642     NC백화점
# 346576      서울특별시 노원구 섬밭로    285    NaN  1135010600105040001010530   중계그린아파트
#
#                         도로명주소   구우편번호   신우편번호  동정보  층정보  호정보          경도  \
# 0           서울특별시 강동구 고덕로 333  134082  5224.0  NaN  NaN  NaN  127.159471
# 1         서울특별시 마포구 동교로38안길 7  121867  3982.0  NaN  NaN  NaN  126.924660
# 2        서울특별시 마포구 잔다리로3안길 23  121840  4043.0  NaN  NaN  NaN  126.919845
# 3          서울특별시 관악구 신림로14길 3  151856  8839.0  NaN  NaN  NaN  126.937790
# 4           서울특별시 송파구 오금로 527  138110  5768.0  NaN    1  NaN  127.147321
# ...                       ...     ...     ...  ...  ...  ...         ...
# 346572   서울특별시 성동구 뚝섬로 366-72  133819  4775.0  NaN  NaN  NaN  127.051154
# 346573     서울특별시 성북구 동소문로 315  136719  2730.0  NaN    5  NaN  127.028726
# 346574  서울특별시 강북구 노해로17길 62-1  142872  1075.0  NaN  NaN  101  127.018733
# 346575    서울특별시 구로구 구로중앙로 152  152715  8292.0  NaN    1  NaN  126.882409
# 346576      서울특별시 노원구 섬밭로 285  139863  1773.0  NaN  NaN  207  127.062556
#
#                위도
# 0       37.556197
# 1       37.562176
# 2       37.550689
# 3       37.471190
# 4       37.493054
# ...           ...
# 346572  37.539464
# 346573  37.608392
# 346574  37.640485
# 346575  37.501378
# 346576  37.640913
#
# [346577 rows x 39 columns]

# %% [markdown]
# ## 인덱스 정보 보기

# %%
df.index
# Out:
# RangeIndex(start=0, stop=346577, step=1)

# %% [markdown]
# ## 컬럼명 보기

# %%
df.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %% [markdown]
# ## 결측치 확인하기

# %%
import missingno as msno
True==1
# Out:
# True

# %% [markdown]
# ### 데이터 프레임 결측치 시각화

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# + 하얀 부분이 결측치

# %%
msno.heatmap(df)
# Out:
# <AxesSubplot:>

# %%
n=df.isnull().sum()
plt.title('<열의 결측치>')
n.sort_values().plot.barh(figsize=(7, 8))
# Out:
# <AxesSubplot:title={'center':'<열의 결측치>'}>

# %% [markdown]
# ### 결측치가 많은 컬럼이나 사용하지 않는 컬럼 제거

# %% [markdown]
# #### 결측치가 너무 많은 컬럼 제거

# %%
# sort_values 를 통해 결측치가 많은 데이터를 위에서 9개 가져와서 not_use 변수로 저장
# not_use 변수에 담긴 인덱스값만 추출해서 not_use_col 변수로 저장
not_use = n.sort_values(ascending=False).head(9)
not_use_col = not_use.index
not_use_col
# Out:
# Index(['동정보', '건물부번지', '호정보', '지점명', '건물명', '층정보', '지번부번지', '표준산업분류코드',
#        '표준산업분류명'],
#       dtype='object')

# %%
# 사용하지 않는 컬럼을 제거
df = df.drop(not_use_col, axis=1)

# %% [markdown]
# #### 사용하지 않는 컬럼 제거

# %%
# 컬럼명을 전처리 하기 위해 cols 라는 변수에 저장
cols = df.columns
cols
# Out:
# Index(['상가업소번호', '상호명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드', '상권업종중분류명',
#        '상권업종소분류코드', '상권업종소분류명', '시도코드', '시도명', '시군구코드', '시군구명', '행정동코드',
#        '행정동명', '법정동코드', '법정동명', '지번코드', '대지구분코드', '대지구분명', '지번본번지', '지번주소',
#        '도로명코드', '도로명', '건물본번지', '건물관리번호', '도로명주소', '구우편번호', '신우편번호', '경도',
#        '위도'],
#       dtype='object')

# %%
# 컬럼명에 "코드", "번호"가 있지만 분석에 필요하지 않기 때문에 
# '코드'와 '번호'를 포함하고 있는 컬럼 찾아와서 cols_code 라는 변수에 저장
cols_code = cols[cols.str.contains("코드|번호")]
cols_code
# Out:
# Index(['상가업소번호', '상권업종대분류코드', '상권업종중분류코드', '상권업종소분류코드', '시도코드', '시군구코드',
#        '행정동코드', '법정동코드', '지번코드', '대지구분코드', '도로명코드', '건물관리번호', '구우편번호',
#        '신우편번호'],
#       dtype='object')

# %%
# "코드", "번호" 가 들어가는 컬럼명만 drop으로 데이터프레임에서 제거
df = df.drop(cols_code, axis=1)

# %%
city="".join(list(df['시도명'].unique()))

# %%
# "상호명"의 문자열을 소문자로 변경한 "상호명_소문자" 컬럼 생성
df["상호명_소문자"] = df["상호명"].str.lower()

# %%
df
# Out:
#               상호명 상권업종대분류명    상권업종중분류명   상권업종소분류명    시도명 시군구명    행정동명   법정동명  \
# 0       도전최강달인왕만두       음식          한식  한식/백반/한정식  서울특별시  강동구    고덕2동    고덕동
# 1              이때       음식          한식  한식/백반/한정식  서울특별시  마포구     연남동    연남동
# 2           L.A.D       음식          한식  한식/백반/한정식  서울특별시  마포구     서교동    서교동
# 3         제이씨에스푸드       음식          한식  한식/백반/한정식  서울특별시  관악구     서림동    신림동
# 4          BYC상신점       소매        의복의류   셔츠/내의/속옷  서울특별시  송파구    거여2동    거여동
# ...           ...      ...         ...        ...    ...  ...     ...    ...
# 346572       현대기림       소매     건강/미용식품     건강식품판매  서울특별시  성동구  성수1가1동  성수동1가
# 346573     본현대미아점       소매     건강/미용식품     건강식품판매  서울특별시  성북구    길음2동    길음동
# 346574      오피스알파       소매     건강/미용식품     건강식품판매  서울특별시  강북구    수유3동    수유동
# 346575  앤클라인뉴욕핸드백       소매  가방/신발/액세서리  가방/가죽제품소매  서울특별시  구로구    구로5동    구로동
# 346576      피움테라피    생활서비스     이/미용/건강    비만/피부관리  서울특별시  노원구  중계2.3동    중계동
#
#        대지구분명  지번본번지                    지번주소                도로명  건물본번지  \
# 0         대지    693       서울특별시 강동구 고덕동 693      서울특별시 강동구 고덕로    333
# 1         대지    390    서울특별시 마포구 연남동 390-67  서울특별시 마포구 동교로38안길      7
# 2         대지    395   서울특별시 마포구 서교동 395-112  서울특별시 마포구 잔다리로3안길     23
# 3         대지    118    서울특별시 관악구 신림동 118-33   서울특별시 관악구 신림로14길      3
# 4         대지     36        서울특별시 송파구 거여동 36      서울특별시 송파구 오금로    527
# ...      ...    ...                     ...                ...    ...
# 346572    대지    276  서울특별시 성동구 성수동1가 276-17      서울특별시 성동구 뚝섬로    366
# 346573    대지     20      서울특별시 성북구 길음동 20-1     서울특별시 성북구 동소문로    315
# 346574    대지     36     서울특별시 강북구 수유동 36-37   서울특별시 강북구 노해로17길     62
# 346575    대지    573       서울특별시 구로구 구로동 573    서울특별시 구로구 구로중앙로    152
# 346576    대지    504     서울특별시 노원구 중계동 504-1      서울특별시 노원구 섬밭로    285
#
#                         도로명주소          경도         위도    상호명_소문자
# 0           서울특별시 강동구 고덕로 333  127.159471  37.556197  도전최강달인왕만두
# 1         서울특별시 마포구 동교로38안길 7  126.924660  37.562176         이때
# 2        서울특별시 마포구 잔다리로3안길 23  126.919845  37.550689      l.a.d
# 3          서울특별시 관악구 신림로14길 3  126.937790  37.471190    제이씨에스푸드
# 4           서울특별시 송파구 오금로 527  127.147321  37.493054     byc상신점
# ...                       ...         ...        ...        ...
# 346572   서울특별시 성동구 뚝섬로 366-72  127.051154  37.539464       현대기림
# 346573     서울특별시 성북구 동소문로 315  127.028726  37.608392     본현대미아점
# 346574  서울특별시 강북구 노해로17길 62-1  127.018733  37.640485      오피스알파
# 346575    서울특별시 구로구 구로중앙로 152  126.882409  37.501378  앤클라인뉴욕핸드백
# 346576      서울특별시 노원구 섬밭로 285  127.062556  37.640913      피움테라피
#
# [346577 rows x 17 columns]

# %% [markdown]
# ## 분석할 카페 데이터 준비

# %%
cafe_name=['스타벅스','투썸플레이스','엔제리너스','메가커피','이디야']
cafe_list=[['스타벅스','스타벅스|starbucks','green','Greens'],
           ['투썸플레이스','투썸|twosme+|twosome|twosom','red','Reds'],
           ['엔제리너스','엔젤리너스|엔젤리러스|엔제리너스','saddlebrown','YlOrBr'],
           ['메가커피','메가커피|mega|메가엠지씨','orange','Oranges'],
           ['이디야','이디야|이디아|ediya','blue','Blues']]

# %%
while True:
    print("카페 브랜드 : "+",".join(cafe_name))
    print('분석하고 싶은 카페 브랜드명 두가지를 입력하세요!')
    cafe_1=input('첫번째 카페 : ')
    cafe_2=input('두번째 카페 : ')
    if (cafe_1 not in cafe_name) or (cafe_2 not in cafe_name) :
        print('분석할 카페 이름이 잘 못 입력되었습니다!')
    elif cafe_1 == cafe_2 : 
        print('분석할 카페가 동일합니다. 서로 다른 카페를 선택해주세요!')
    else:
        cafe_1=cafe_list[cafe_name.index(cafe_1)]
        cafe_2=cafe_list[cafe_name.index(cafe_2)]
        break
    print('---------------------------------------------------\n')
# Out:
# 카페 브랜드 : 스타벅스,투썸플레이스,엔제리너스,메가커피,이디야
# 분석하고 싶은 카페 브랜드명 두가지를 입력하세요!
# 첫번째 카페 : 스타벅스
# 두번째 카페 : 이디야

# %%
# 분석할 카페 데이터들 df_cafe에 저장
df_cafe = df[(df["상권업종중분류명"]=='커피점/카페') & (df["상호명_소문자"].str.contains('{}|{}'.format(cafe_1[1],cafe_2[1]),na=False))]

# %%
df_cafe.loc[df_cafe["상호명_소문자"].str.contains(cafe_1[1]), "브랜드명"] = cafe_1[0]
df_cafe.loc[~df_cafe["상호명_소문자"].str.contains(cafe_1[1]), "브랜드명"] = cafe_2[0]
df_cafe = df_cafe.drop(['상호명','상호명_소문자','상권업종대분류명', '상권업종중분류명', '상권업종소분류명'], axis=1)
df_cafe
# Out:
#           시도명  시군구명  행정동명   법정동명 대지구분명  지번본번지                  지번주소  \
# 778     서울특별시   종로구   이화동    동숭동    대지      1    서울특별시 종로구 동숭동 1-28
# 1656    서울특별시   강남구  대치4동    대치동    대지    936  서울특별시 강남구 대치동 936-15
# 1752    서울특별시  영등포구  신길1동    신길동    대지     59   서울특별시 영등포구 신길동 59-2
# 1797    서울특별시    중구   소공동  태평로2가    대지     52   서울특별시 중구 태평로2가 52-4
# 2076    서울특별시   종로구   이화동    동숭동    대지     30      서울특별시 종로구 동숭동 30
# ...       ...   ...   ...    ...   ...    ...                   ...
# 341109  서울특별시   서초구  반포4동    반포동    대지     52    서울특별시 서초구 반포동 52-6
# 341204  서울특별시   강남구  일원2동    개포동    대지     14    서울특별시 강남구 개포동 14-1
# 341225  서울특별시   강남구  역삼1동    역삼동    대지    736   서울특별시 강남구 역삼동 736-1
# 341502  서울특별시   강남구  역삼1동    역삼동    대지    679     서울특별시 강남구 역삼동 679
# 341583  서울특별시  동대문구  전농2동    전농동    대지     39  서울특별시 동대문구 전농동 39-18
#
#                       도로명  건물본번지                 도로명주소          경도         위도  \
# 778         서울특별시 종로구 대학로    122     서울특별시 종로구 대학로 122  127.002233  37.582185
# 1656     서울특별시 강남구 선릉로64길     18   서울특별시 강남구 선릉로64길 18  127.053715  37.497946
# 1752      서울특별시 영등포구 영등포로    353   서울특별시 영등포구 영등포로 353  126.918062  37.515118
# 1797      서울특별시 중구 남대문로1길     57  서울특별시 중구 남대문로1길 57-1  126.977556  37.563637
# 2076        서울특별시 종로구 동숭길    110     서울특별시 종로구 동숭길 110  127.003887  37.582964
# ...                   ...    ...                   ...         ...        ...
# 341109    서울특별시 서초구 서초중앙로    225   서울특별시 서초구 서초중앙로 225  127.011539  37.501655
# 341204  서울특별시 강남구 개포로109길     34  서울특별시 강남구 개포로109길 34  127.077635  37.494197
# 341225     서울특별시 강남구 테헤란로    142    서울특별시 강남구 테헤란로 142  127.034941  37.499740
# 341502      서울특별시 강남구 논현로    508     서울특별시 강남구 논현로 508  127.037277  37.501886
# 341583    서울특별시 동대문구 사가정로    132   서울특별시 동대문구 사가정로 132  127.059501  37.577591
#
#         브랜드명
# 778     스타벅스
# 1656    스타벅스
# 1752     이디야
# 1797     이디야
# 2076    스타벅스
# ...      ...
# 341109  스타벅스
# 341204   이디야
# 341225  스타벅스
# 341502  스타벅스
# 341583   이디야
#
# [1023 rows x 13 columns]

# %% [markdown]
# # 분석

# %% [markdown]
# ## 브랜드명으로 각 카페의 수

# %%
df_cafe["브랜드명"].value_counts()
# Out:
# 이디야     513
# 스타벅스    510
# Name: 브랜드명, dtype: int64

# %% [markdown]
# ## 브랜드명으로 막대그래프

# %%
sns.countplot(data=df_cafe, x="브랜드명")
plt.title('<{}의 {}와 {}의 점포수>'.format(city,cafe_1[0],cafe_2[0]))
# Out:
# Text(0.5, 1.0, '<서울특별시의 스타벅스와 이디야의 점포수>')

# %% [markdown]
# ## 시군구별 점포수

# %%
plt.figure(figsize=(15, 4))
sns.countplot(data=df_cafe, x="시군구명", hue="브랜드명")
plt.title('<{}의 구별 {}와 {}의 점포수>'.format(city,cafe_1[0],cafe_2[0]))
# Out:
# Text(0.5, 1.0, '<서울특별시의 구별 스타벅스와 이디야의 점포수>')

# %% [markdown]
# ## 위도, 경도로 scatterplot 그리기

# %%
sns.scatterplot(data=df_cafe, x="경도", y="위도", hue="브랜드명")
plt.title('<{}의 구별 {}와 {}의 점포수>'.format(city,cafe_1[0],cafe_2[0]))
# Out:
# Text(0.5, 1.0, '<서울특별시의 구별 스타벅스와 이디야의 점포수>')

# %%
sns.scatterplot(data=df_cafe[df_cafe['브랜드명']==cafe_1[0]], x="경도", y="위도",color=cafe_1[2])
plt.title('<{}의 구별 {}>'.format(city,cafe_1[0]))
# Out:
# Text(0.5, 1.0, '<서울특별시의 구별 스타벅스>')

# %%
sns.scatterplot(data=df_cafe[df_cafe['브랜드명']==cafe_2[0]], x="경도", y="위도",color=cafe_2[2])
plt.title('<{}의 구별 {}>'.format(city,cafe_2[0]))
# Out:
# Text(0.5, 1.0, '<서울특별시의 구별 이디야>')

# %% [markdown]
# ## 브랜드별 구별 점포 수

# %%
# groupby 를 사용해 구별로 그룹화
# 그룹화한 결과를 df_cafe_vs 변수에 담아서 재사용합니다.
df_cafe_vs = df_cafe.groupby(["시군구명", "브랜드명"])["경도"].count()
df_cafe_vs = df_cafe_vs.reset_index()
df_cafe_vs.columns = ['구', '브랜드명', '매장수']
df_cafe_vs.head()
# Out:
#      구  브랜드명  매장수
# 0  강남구  스타벅스   87
# 1  강남구   이디야   45
# 2  강동구  스타벅스   15
# 3  강동구   이디야   16
# 4  강북구  스타벅스    5

# %%
# seaborn의 barplot 을 활용해 구별 매장수를 시각화 합니다.
plt.figure(figsize=(15, 4))
sns.barplot(data=df_cafe_vs.sort_values("매장수", ascending=False), x="구", y="매장수", hue="브랜드명")
plt.title('<{}의 시군구별 {}와 {}의 점포수>'.format(city,cafe_1[0],cafe_2[0]))
# Out:
# Text(0.5, 1.0, '<서울특별시의 시군구별 스타벅스와 이디야의 점포수>')

# %%
# seaborn의 barplot 을 활용해 구별 매장수를 시각화 합니다.
plt.figure(figsize=(15, 4))
sns.barplot(data=df_cafe_vs[df_cafe_vs['브랜드명']==cafe_1[0]].sort_values("매장수", ascending=False), x="구", y="매장수")#, hue="브랜드명")
plt.title('<{}의 시군구별 {} 점포수>'.format(city,cafe_1[0]))
# Out:
# Text(0.5, 1.0, '<서울특별시의 시군구별 스타벅스 점포수>')

# %%
# seaborn의 barplot 을 활용해 구별 매장수를 시각화 합니다.
plt.figure(figsize=(15, 4))
sns.barplot(data=df_cafe_vs[df_cafe_vs['브랜드명']==cafe_2[0]].sort_values("매장수", ascending=False), x="구", y="매장수")#, hue="브랜드명")
plt.title('<{}의 시군구별 {} 점포수>'.format(city,cafe_2[0]))
# Out:
# Text(0.5, 1.0, '<서울특별시의 시군구별 이디야 점포수>')

# %%
lat=df_cafe["위도"].mean()
long=df_cafe["경도"].mean()
lat, long
# Out:
# (37.54161520051652, 126.99018424793628)

# %%
m = folium.Map([lat, long], zoom_start=12, tiles="Stamen Toner")
for i in df_cafe.index:
    sub_lat = df_cafe.loc[i, "위도"]
    sub_long = df_cafe.loc[i, "경도"]
    title = f"{df_cafe.loc[i, '브랜드명']} - {df_cafe.loc[i, '도로명주소']}"
    color = cafe_1[2]
    if df_cafe.loc[i, "브랜드명"] == cafe_2[0]:
        color = cafe_2[2]
    folium.CircleMarker([sub_lat, sub_long],
                        radius=3,
                        color=color,
                          tooltip=title).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_44b1a5d8420448a68ec18e9d83478eb8%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_44b1a5d8420448a68ec18e9d83478eb8%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_44b1a5d8420448a68ec18e9d83478eb8%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_44b1a5d8420448a68ec18e9d83478eb8%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.54161520051652%2C%20126.99018424793628%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
geo_path = 'data/seoul_municipalities_geo_simple.json'
geo_json = json.load(open(geo_path, encoding="utf-8"))

# %%
df_1 = df_cafe_vs[df_cafe_vs["브랜드명"] == cafe_1[0]]
df_2 = df_cafe_vs[df_cafe_vs["브랜드명"] == cafe_2[0]]

# %%
m = folium.Map([lat, long],tiles='cartodbpositron')

folium.Choropleth(
    geo_data=geo_json,
    name='choropleth',
    data=df_1,
    columns=['구', '매장수'],
    key_on='feature.properties.SIG_KOR_NM',
    fill_color=cafe_1[-1],
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='{} 매장수'.format(cafe_1[0])
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c42f88e2ffdc444abbd8c28dec24546d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c42f88e2ffdc444abbd8c28dec24546d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c42f88e2ffdc444abbd8c28dec24546d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_c42f88e2ffdc444abbd8c28dec24546d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
m = folium.Map([lat, long],tiles='cartodbpositron')
folium.Choropleth(
    geo_data=geo_json,
    name='choropleth',
    data=df_2,
    columns=['구', '매장수'],
    key_on='feature.properties.SIG_KOR_NM',
    fill_color=cafe_2[-1],
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='{} 매장수'.format(cafe_2[0])
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a0a74703e1ae4083b58dab4f601eace5%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a0a74703e1ae4083b58dab4f601eace5%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a0a74703e1ae4083b58dab4f601eace5%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a0a74703e1ae4083b58dab4f601eace5%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...
